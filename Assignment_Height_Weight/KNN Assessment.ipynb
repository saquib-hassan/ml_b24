# %%
import pandas as pd 
import warnings as wr 
wr.filterwarnings('ignore')

# %%
df = pd.read_csv('weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.Gender = le.fit_transform(df[['Gender']])

# %%
df.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
df.tail()
# Out:
#       Gender     Height      Weight
# 8550       0  60.483946  110.565497
# 8551       0  63.423372  129.921671
# 8552       0  65.584057  155.942671
# 8553       0  67.429971  151.678405
# 8554       0  60.921791  131.253738

# %% [markdown]
# # Go Ahead

# %% [markdown]
# #
#  2. Separate X (Gender, Height) and Y (y=Weight).
#  3. Train = 70%, Test = 30%
#  4. Apply Linear Regression
#  5. Evaluate the Model (Testing and training Accuracy, MSE for testing)
#  6. Apply KNN Regressor:
# Scikit-Learn Link
#  7. Evaluate the Model (Testing and training Accuracy, MSE for testing)
#  8. Compare KNN & Linear Regression with the KNN Model and Linear regression as well.

# %%
df.shape
# Out:
# (8555, 3)

# %%
X = df.drop(["Weight"], axis = 1)

# %%
X.head()
# Out:
#    Gender     Height
# 0       1  73.847017
# 1       1  68.781904
# 2       1  74.110105
# 3       1  71.730978
# 4       1  69.881796

# %%
X.shape
# Out:
# (8555, 2)

# %%
Y = df.Weight

# %%
Y.head()
# Out:
# 0    241.893563
# 1    162.310473
# 2    212.740856
# 3    220.042470
# 4    206.349801
# Name: Weight, dtype: float64

# %%
Y.shape
# Out:
# (8555,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,Y, test_size = 0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(xtest)

# %%
y_pred
# Out:
# array([142.44868114, 186.0517281 , 198.42283706, ..., 102.94080643,
#        190.83713617, 143.34786753])

# %%
xtest
# Out:
#       Gender     Height
# 6006       0  64.846644
# 1197       1  68.886367
# 2862       1  70.963369
# 6497       0  62.737189
# 2860       1  69.578030
# ...      ...        ...
# 184        1  71.935887
# 2988       1  67.616383
# 6048       0  58.213614
# 420        1  69.689795
# 5669       0  64.997610
#
# [2567 rows x 2 columns]

# %%
from sklearn.metrics import r2_score

# %%
lr_train = model.score(xtrain,ytrain)

# %%
lr_train
# Out:
# 0.8973793060969246

# %%
r2_score(ytest,y_pred)
# Out:
# 0.905911242442266

# %%
lr_test =model.score(xtest,ytest)

# %%
lr_test
# Out:
# 0.905911242442266

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(ytest,y_pred)

# %%
mse
# Out:
# 96.83734437830608

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_reg = KNeighborsRegressor()

# %%
knn_reg.fit(xtrain,ytrain)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knr = knn_reg.predict(xtest)

# %%
y_pred_knr
# Out:
# array([142.1445657 , 181.38276924, 187.07075266, ..., 101.79654426,
#        192.43702356, 145.3632227 ])

# %%
knr_train = knn_reg.score(xtrain,ytrain)

# %%
knr_train
# Out:
# 0.9172142723737918

# %%
knr_test = knn_reg.score(xtest,ytest)

# %%
knr_test
# Out:
# 0.8821086423439015

# %%
mse = mean_squared_error(ytest, y_pred_knr)

# %%
mse
# Out:
# 121.33528273624482

# %% [markdown]
# #  1. Import data set
#  2. Separate X and Y. (y=Gender)
#  3. Train = 70%, Test = 30%
#  4. Apply KNN Classifier
# 5. Evaluate the Model by only Accuracy.
#  6. Apply KNN Classifier:
# Scikit-Learn Link

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
df.head()
# Out:
#    Gender     Height      Weight
# 0       1  73.847017  241.893563
# 1       1  68.781904  162.310473
# 2       1  74.110105  212.740856
# 3       1  71.730978  220.042470
# 4       1  69.881796  206.349801

# %%
X = df2.drop(["Gender"], axis =1)

# %%
X.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
X.shape
# Out:
# (8555, 2)

# %%
Y = df2.Gender

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Gender, dtype: int32

# %%
Y.tail()
# Out:
# 8550    0
# 8551    0
# 8552    0
# 8553    0
# 8554    0
# Name: Gender, dtype: int32

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,Y, train_size = 0.7, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_cls = KNeighborsClassifier()

# %%
knn_cls.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
xtest.shape
# Out:
# (2567, 2)

# %%
y_pred = knn_cls.predict(xtest)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
knn_acc = accuracy_score(ytest, y_pred)

# %%
knn_acc
# Out:
# 0.9131281651733542

# %%
from sklearn.linear_model import LogisticRegression

# %%
logi_reg = LogisticRegression()

# %%
logi_reg.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
y_pred_logi = logi_reg.predict(xtest)

# %%
y_pred_logi
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
logi_acc = accuracy_score(ytest, y_pred_logi)

# %%
logi_acc
# Out:
# 0.9185820023373588

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure()
labels = ['LR Train','LR Test','KNN Train','KNN Test']
scores = [lr_train, lr_test, knr_train, knr_test]
plt.bar(labels, scores)
plt.ylim(0,1)
plt.ylabel('Score')
plt.title('Linear Regression vs KNN Regressor')
plt.tight_layout()
plt.show()

plt.figure()
labels = ['KNN Classifier','Logistic Regression']
scores = [knn_acc, logi_acc]
plt.bar(labels, scores)
plt.ylim(0,1)
plt.ylabel('Accuracy')
plt.title('KNN Classifier vs Logistic Regression')
plt.tight_layout()
plt.show()
